# %%
e=int(input("Ingrese su edad "))

if e>=65:
    print("Adulto Mayor ")
    print(e)

elif e<=64 and e>=18:
    print("Adulto")
    print(e)

elif e<=17 and e>=12:
    print("Adolescente ")
    print(e)

else :
    print("Niño / Niña ")
    print(e)
# Out:
# Ingrese su edad 65
# Adulto Mayor
# 65
